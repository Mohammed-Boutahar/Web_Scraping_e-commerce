# %%
pip install google-play-scraper

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np

#US Market

from google_play_scraper import Sort, reviews_all


us_reviews = reviews_all(
    'com.block.juggle',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

df_busu = pd.DataFrame(np.array(us_reviews),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head(20)
# Out:
#                                 reviewId  \
# 0   63138084-b71c-47bc-b1f0-249e08856dd3
# 1   a8b09993-d745-4c6c-b76c-acd1e19e4004
# 2   6e3df0c4-7d01-47e6-8645-817c20c016e4
# 3   8754e56a-67d8-48c3-979b-0705af491626
# 4   cc42b7c5-dd2f-4e34-9851-5620c3dc382a
# 5   267fe938-344e-44cd-9314-2ceb0c8f96f8
# 6   bded4e1a-bc30-4350-8445-f1bb42ddd0b8
# 7   a96fdd16-241b-4361-ab22-30676fb182b8
# 8   427ad17b-440c-4b55-86b6-352546ac7018
# 9   f3cb5b95-0dda-4487-a662-255e58603783
# 10  d1f6882c-a301-4af6-aff8-9609a70e88f2
# 11  46652837-a283-40ef-8e2b-ee51da87db40
# 12  53963dc0-7e92-42de-b3ef-f14e2cb3fbb9
# 13  149a1e15-dac8-4363-942a-8a5a4be3ec40
# 14  4045ce8e-9c44-49d2-ae02-8c0a522492f6
# 15  273992f2-cd4f-40c6-a755-1afafddd9163
# 16  1376a00c-8ab8-48c8-804c-5a2057bd6c4b
# 17  c2f36531-5503-448f-b437-4e8ee72ffbb1
# 18  94d7ea17-cae0-48f9-9d95-5a713c22f497
# 19  d41ab1d5-3224-4646-8d07-f130fe2c110a
#
#                                   userName  \
# ...

# %%
from selenium import webdriver
PATH = "chromedriver.exe"
driver = webdriver.Chrome(executable_path=PATH)

driver.get("https://fr.aliexpress.com/item/1005003444703583.html?spm=a2g0o.productlist.main.27.498a6ee70yWbFn&algo_pvid=fce74983-7c27-41f5-9fca-da436e5d94c6&algo_exp_id=fce74983-7c27-41f5-9fca-da436e5d94c6-13&pdp_ext_f=%7B%22sku_id%22%3A%2212000030854261448%22%7D&pdp_npi=3%40dis%21EUR%21300.77%21150.38%21%21%21%21%21%402102186a16770840826613065d0700%2112000030854261448%21sea%21FR%212672294025&curPageLogUid=KA5Ygxr8ljp5")
print(driver.title)
driver.quit()
# Out:
# Airrobo – Robot Aspirateur P10 Pour Maison, Robot Intelligent, Puissant, Avec Base, 2600pa, Pour Le Nettoyage À Sec - Aspirateurs - AliExpress
